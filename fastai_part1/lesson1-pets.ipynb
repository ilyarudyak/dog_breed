# %% [markdown]
# # Lesson 1 - What's your pet

# %% [markdown]
# Welcome to lesson 1! For those of you who are using a Jupyter Notebook for the first time, you can learn about this useful tool in a tutorial we prepared specially for you; click `File`->`Open` now and click `00_notebook_tutorial.ipynb`.
#
# In this lesson we will build our first image classifier from scratch, and see if we can achieve world-class results. Let's dive in!
#
# Every notebook starts with the following three lines; they ensure that any edits to libraries you make are reloaded here automatically, and also that any charts or images displayed are shown in this notebook.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# We import all the necessary packages. We are going to work with the [fastai V1 library](http://www.fast.ai/2018/10/02/fastai-ai/) which sits on top of [Pytorch 1.0](https://hackernoon.com/pytorch-1-0-468332ba5163). The fastai library provides many useful functions that enable us to quickly and easily build neural networks and train our models.

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %% [markdown]
# If you're using a computer with an unusually small GPU, you may get an out of memory error when running this notebook. If this happens, click Kernel->Restart, uncomment the 2nd line below to use a smaller *batch size* (you'll learn all about what this means during the course), and try again.

# %%
bs = 64
# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %% [markdown]
# ## Looking at the data

# %% [markdown]
# We are going to use the [Oxford-IIIT Pet Dataset](http://www.robots.ox.ac.uk/~vgg/data/pets/) by [O. M. Parkhi et al., 2012](http://www.robots.ox.ac.uk/~vgg/publications/2012/parkhi12a/parkhi12a.pdf) which features 12 cat breeds and 25 dogs breeds. Our model will need to learn to differentiate between these 37 distinct categories. According to their paper, the best accuracy they could get in 2012 was 59.21%, using a complex model that was specific to pet detection, with separate "Image", "Head", and "Body" models for the pet photos. Let's see how accurate we can be using deep learning!
#
# We are going to use the `untar_data` function to which we must pass a URL as an argument and which will download and extract the data.

# %%
help(untar_data)
# Out:
# Help on function untar_data in module fastai.datasets:
#
# untar_data(url:str, fname:Union[pathlib.Path, str]=None, dest:Union[pathlib.Path, str]=None, data=True, force_download=False) -> pathlib.Path
#     Download `url` to `fname` if `dest` doesn't exist, and un-tgz to folder `dest`.

# %% [markdown]
# <span style="color:blue"> ============my comments============ </span>
#
# Let's explore how do we download data. First of all `URLs.PETS` is an `URL` of some `xml` document that probably contains the actual `URL`.
#
# Where do we store the file? The locations where the data and models are downloaded are set in `config.yml`, which by default is located in `~/.fastai`. So it seems data is stored in `~/.fastai/data`.
#
# <span style="color:blue"> ============my comments============ </span>

# %%
URLs.PETS
# Out:
# 'https://s3.amazonaws.com/fast-ai-imageclas/oxford-iiit-pet'

# %%
# !cat ~/.fastai/config.yml
# Out:
# cat: /home/ilyarudyak/.fastai/config.yml: No such file or directory

# %%
path = untar_data(URLs.PETS)
path, type(path)
# Out:
# (PosixPath('/home/ilyarudyak/.fastai/data/oxford-iiit-pet'), pathlib.PosixPath)

# %% [markdown]
# <span style="color:blue"> ============my comments============ </span>
#
# How can we do `path.ls()`? Looks like it's method of `PosixPath` class.

# %%
from pathlib import Path

# %%
path2 = Path.home() / '.fastai/data/oxford-iiit-pet'

# %%
path2
# Out:
# PosixPath('/home/ilyarudyak/.fastai/data/oxford-iiit-pet')

# %%
'ls' in dir(path2)
# Out:
# True

# %%
path2.ls()
# Out:
# [PosixPath('/home/ilyarudyak/.fastai/data/oxford-iiit-pet/annotations'),
#  PosixPath('/home/ilyarudyak/.fastai/data/oxford-iiit-pet/images')]

# %% [markdown]
# <span style="color:blue"> ============my comments============ </span>

# %%
path.ls()
# Out:
# [PosixPath('/home/ilyarudyak/.fastai/data/oxford-iiit-pet/annotations'),
#  PosixPath('/home/ilyarudyak/.fastai/data/oxford-iiit-pet/images')]

# %%
path_anno = path/'annotations'
path_img = path/'images'

# %%
path_anno, path_img
# Out:
# (PosixPath('/home/ilyarudyak/.fastai/data/oxford-iiit-pet/annotations'),
#  PosixPath('/home/ilyarudyak/.fastai/data/oxford-iiit-pet/images'))

# %% [markdown]
# The first thing we do when we approach a problem is to take a look at the data. We _always_ need to understand very well what the problem is and what the data looks like before we can figure out how to solve it. Taking a look at the data means understanding how the data directories are structured, what the labels are and what some sample images look like.
#
# The main difference between the handling of image classification datasets is the way labels are stored. In this particular dataset, **labels are stored in the filenames themselves**. We will need to extract them to be able to classify the images into the correct categories. Fortunately, the fastai library has a handy function made exactly for this, `ImageDataBunch.from_name_re` gets the labels from the filenames using a [regular expression](https://docs.python.org/3.6/library/re.html).

# %% [markdown]
# <span style="color:blue"> ============my comments============ </span>

# %%
# !tree -d ~/.fastai/data/oxford-iiit-pet
# Out:
# /home/ilyarudyak/.fastai/data/oxford-iiit-pet
# ├── annotations
# │   ├── trimaps
# │   └── xmls
# └── images
#
# 4 directories

# %%
path_img.ls()[:5]
# Out:
# [PosixPath('/home/ilyarudyak/.fastai/data/oxford-iiit-pet/images/beagle_138.jpg'),
#  PosixPath('/home/ilyarudyak/.fastai/data/oxford-iiit-pet/images/Sphynx_236.jpg'),
#  PosixPath('/home/ilyarudyak/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_107.jpg'),
#  PosixPath('/home/ilyarudyak/.fastai/data/oxford-iiit-pet/images/newfoundland_149.jpg'),
#  PosixPath('/home/ilyarudyak/.fastai/data/oxford-iiit-pet/images/saint_bernard_160.jpg')]

# %%
type(get_image_files(path_img)), type(get_image_files(path_img)[0])
# Out:
# (list, pathlib.PosixPath)

# %% [markdown]
# <span style="color:blue"> ============my comments============ </span>

# %%
fnames = get_image_files(path_img)
fnames[:5], len(fnames)
# Out:
# ([PosixPath('/home/ilyarudyak/.fastai/data/oxford-iiit-pet/images/beagle_138.jpg'),
#   PosixPath('/home/ilyarudyak/.fastai/data/oxford-iiit-pet/images/Sphynx_236.jpg'),
#   PosixPath('/home/ilyarudyak/.fastai/data/oxford-iiit-pet/images/wheaten_terrier_107.jpg'),
#   PosixPath('/home/ilyarudyak/.fastai/data/oxford-iiit-pet/images/newfoundland_149.jpg'),
#   PosixPath('/home/ilyarudyak/.fastai/data/oxford-iiit-pet/images/saint_bernard_160.jpg')],
#  7390)

# %%
np.random.seed(2)
pat = r'/([^/]+)_\d+.jpg$'

# %%
data = ImageDataBunch.from_name_re(path_img, 
                                   fnames, 
                                   pat, 
                                   ds_tfms=get_transforms(), 
                                   size=224, 
                                   bs=bs,
                                   num_workers=0
                                  ).normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
print(data.classes)
len(data.classes), data.c
# Out:
# ['Abyssinian', 'Bengal', 'Birman', 'Bombay', 'British_Shorthair', 'Egyptian_Mau', 'Maine_Coon', 'Persian', 'Ragdoll', 'Russian_Blue', 'Siamese', 'Sphynx', 'american_bulldog', 'american_pit_bull_terrier', 'basset_hound', 'beagle', 'boxer', 'chihuahua', 'english_cocker_spaniel', 'english_setter', 'german_shorthaired', 'great_pyrenees', 'havanese', 'japanese_chin', 'keeshond', 'leonberger', 'miniature_pinscher', 'newfoundland', 'pomeranian', 'pug', 'saint_bernard', 'samoyed', 'scottish_terrier', 'shiba_inu', 'staffordshire_bull_terrier', 'wheaten_terrier', 'yorkshire_terrier']
# (37, 37)

# %% [markdown]
# ## Training: resnet34

# %% [markdown]
# Now we will start training our model. We will use a [convolutional neural network](http://cs231n.github.io/convolutional-networks/) backbone and a fully connected head with a single hidden layer as a classifier. Don't know what these things mean? Not to worry, we will dive deeper in the coming lessons. For the moment you need to know that we are building a model which will take images as input and will output the predicted probability for each of the categories (in this case, it will have 37 outputs).
#
# We will train for 4 epochs (4 cycles through all our data).

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /home/ilyarudyak/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 83.3M/83.3M [00:02<00:00, 37.5MB/s]

# %%
learn.model;

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.377217</td>
#       <td>0.325719</td>
#       <td>0.111637</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.626110</td>
#       <td>0.299450</td>
#       <td>0.093369</td>
#       <td>01:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.395231</td>
#       <td>0.241932</td>
#       <td>0.080514</td>
#       <td>01:29</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.273696</td>
#       <td>0.227022</td>
#       <td>0.070365</td>
#       <td>01:29</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %% [markdown]
# ## Results

# %% [markdown]
# Let's see what results we have got.
#
# We will first see which were the categories that the model most confused with one another. We will try to see if what the model predicted was reasonable or not. In this case the mistakes look reasonable (none of the mistakes seems obviously naive). This is an indicator that our classifier is working correctly.
#
# Furthermore, when we plot the confusion matrix, we can see that the distribution is heavily skewed: the model makes the same mistakes over and over again but it rarely confuses other categories. This suggests that it just finds it difficult to distinguish some specific categories between each other; this is normal behaviour.

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
doc(interp.plot_top_losses)

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('Bengal', 'Egyptian_Mau', 6),
#  ('Ragdoll', 'Birman', 5),
#  ('american_pit_bull_terrier', 'staffordshire_bull_terrier', 5),
#  ('staffordshire_bull_terrier', 'american_pit_bull_terrier', 5),
#  ('chihuahua', 'miniature_pinscher', 4),
#  ('samoyed', 'great_pyrenees', 4),
#  ('american_pit_bull_terrier', 'miniature_pinscher', 3),
#  ('boxer', 'american_bulldog', 3),
#  ('keeshond', 'leonberger', 3),
#  ('Birman', 'Ragdoll', 2),
#  ('Egyptian_Mau', 'Bengal', 2),
#  ('Maine_Coon', 'Ragdoll', 2),
#  ('Ragdoll', 'Persian', 2),
#  ('Russian_Blue', 'British_Shorthair', 2),
#  ('Sphynx', 'chihuahua', 2),
#  ('american_bulldog', 'american_pit_bull_terrier', 2),
#  ('english_setter', 'english_cocker_spaniel', 2),
#  ('german_shorthaired', 'english_setter', 2),
#  ('miniature_pinscher', 'chihuahua', 2),
#  ('newfoundland', 'leonberger', 2),
#  ('yorkshire_terrier', 'havanese', 2)]

# %% [markdown]
# ## Unfreezing, fine-tuning, and learning rates

# %% [markdown]
# Since our model is working as we expect it to, we will *unfreeze* our model and train some more.

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.713690</td>
#       <td>0.389453</td>
#       <td>0.121786</td>
#       <td>01:37</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-1');

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.238448</td>
#       <td>0.222391</td>
#       <td>0.067659</td>
#       <td>01:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.226790</td>
#       <td>0.216798</td>
#       <td>0.066982</td>
#       <td>01:38</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# That's a pretty accurate model!

# %% [markdown]
# ## Training: resnet50

# %% [markdown]
# Now we will train in the same way as before but with one caveat: instead of using resnet34 as our backbone we will use resnet50 (resnet34 is a 34 layer residual network while resnet50 has 50 layers. It will be explained later in the course and you can learn the details in the [resnet paper](https://arxiv.org/pdf/1512.03385.pdf)).
#
# Basically, resnet50 usually performs better because it is a deeper network with more parameters. Let's see if we can achieve a higher performance here. To help it along, let's us use larger images too, since that way the network can see more detail. We reduce the batch size a bit since otherwise this larger network will require more GPU memory.

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(),
                                   size=299, bs=bs//2).normalize(imagenet_stats)

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate)

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.720011</td>
#       <td>0.332501</td>
#       <td>0.100812</td>
#       <td>01:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.474362</td>
#       <td>0.295959</td>
#       <td>0.087280</td>
#       <td>01:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.435661</td>
#       <td>0.253062</td>
#       <td>0.077808</td>
#       <td>01:29</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.323249</td>
#       <td>0.246630</td>
#       <td>0.077808</td>
#       <td>01:29</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.280578</td>
#       <td>0.192447</td>
#       <td>0.061570</td>
#       <td>01:29</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.186112</td>
#       <td>0.170684</td>
#       <td>0.059540</td>
#       <td>01:29</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.131221</td>
#       <td>0.157748</td>
#       <td>0.052097</td>
#       <td>01:29</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.115702</td>
#       <td>0.161483</td>
#       <td>0.053451</td>
#       <td>01:29</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-50')

# %% [markdown]
# It's astonishing that it's possible to recognize pet breeds so accurately! Let's see if full fine-tuning helps:

# %%
learn.unfreeze()
learn.fit_one_cycle(3, max_lr=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.111873</td>
#       <td>0.168798</td>
#       <td>0.053451</td>
#       <td>02:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.116712</td>
#       <td>0.154666</td>
#       <td>0.049391</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.085256</td>
#       <td>0.151135</td>
#       <td>0.048714</td>
#       <td>02:01</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# If it doesn't, you can always go back to your previous model.

# %%
learn.load('stage-1-50');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-119754ed3d78> in <module>
# ----> 1 learn.load('stage-1-50');
#
# NameError: name 'learn' is not defined

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.most_confused(min_val=2)

# %% [markdown]
# ## Other data formats

# %%
path = untar_data(URLs.MNIST_SAMPLE); path

# %%
tfms = get_transforms(do_flip=False)
data = ImageDataBunch.from_folder(path, ds_tfms=tfms, size=26)

# %%
data.show_batch(rows=3, figsize=(5,5))

# %%
learn = cnn_learner(data, models.resnet18, metrics=accuracy)
learn.fit(2)

# %%
df = pd.read_csv(path/'labels.csv')
df.head()

# %%
data = ImageDataBunch.from_csv(path, ds_tfms=tfms, size=28)

# %%
data.show_batch(rows=3, figsize=(5,5))
data.classes

# %%
data = ImageDataBunch.from_df(path, df, ds_tfms=tfms, size=24)
data.classes

# %%
fn_paths = [path/name for name in df['name']]; fn_paths[:2]

# %%
pat = r"/(\d)/\d+\.png$"
data = ImageDataBunch.from_name_re(path, fn_paths, pat=pat, ds_tfms=tfms, size=24)
data.classes

# %%
data = ImageDataBunch.from_name_func(path, fn_paths, ds_tfms=tfms, size=24,
        label_func = lambda x: '3' if '/3/' in str(x) else '7')
data.classes

# %%
labels = [('3' if '/3/' in str(x) else '7') for x in fn_paths]
labels[:5]

# %%
data = ImageDataBunch.from_lists(path, fn_paths, labels=labels, ds_tfms=tfms, size=24)
data.classes
